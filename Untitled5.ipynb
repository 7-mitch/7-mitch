# %% [markdown]
# <a href="https://colab.research.google.com/github/7-mitch/7-mitch/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

data = {
    "user_query": "こんにちは、君の正体は？",
    "ai_response": "私は秘密の組織のAIです...", # ここにモデルの回答を入れる
    "status": "investigating"
}

# n8nのWebhook URLに送信
requests.post("https://nvisio.app.n8n.cloud/webhook-test/ai-test", json=data)
# Out:
# <Response [200]>
